# %% [markdown]
# # Exploratory Data Analysis (EDA)\n\nThis notebook explores the spam email dataset used for training.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns

# %%
df = pd.read_csv('../data/sample_emails.csv')\ndf.head()

# %%
df.info()

# %%
df['label'].value_counts()

# %%
ax = sns.countplot(data=df, x='label')\nax.set_title('Spam vs Ham Distribution')\nplt.show()

# %%
df['email_length'] = df['email'].astype(str).str.len()\ndf[['label', 'email_length']].groupby('label').describe()

# %%
sns.histplot(data=df, x='email_length', hue='label', kde=True, element='step')\nplt.title('Email Length Distribution by Label')\nplt.show()
